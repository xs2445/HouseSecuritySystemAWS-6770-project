# %%
import torch
import numpy as np
import cv2 as cv


model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://github.com/ultralytics/yolov5/raw/master/data/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()
# Out:
# Using cache found in /home/xinghua/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2021-11-28 torch 1.10.0+cu102 CUDA:0 (GeForce GTX 1060 with Max-Q Design, 6078MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# image 1/2: 720x1280 2 persons, 1 tie
# image 2/2: 1080x810 4 persons, 1 bus
# Speed: 361.3ms pre-process, 24.2ms inference, 1.2ms NMS per image at shape (2, 3, 640, 640)

# %%
result_list = results.display(crop=True)

# %%
type(result_list)
print(type(result_list[0]))
for i in range(len(result_list)):
    print(str.split(result_list[i]['label'])[0])
print(result_list)
# Out:
# <class 'dict'>
# tie
# person
# person
# person
# bus
# person
# person
# person
# [{'box': [tensor(438.25000, device='cuda:0'), tensor(422., device='cuda:0'), tensor(510.75000, device='cuda:0'), tensor(720., device='cuda:0')], 'conf': tensor(0.54053, device='cuda:0'), 'cls': tensor(27., device='cuda:0'), 'label': 'tie 0.54', 'im': array([[[ 0,  2,  0],
#         [ 1,  2,  0],
#         [ 2,  3,  1],
#         ...,
#         [ 8, 30, 35],
#         [ 6, 28, 33],
#         [ 5, 27, 32]],
#
#        [[ 1,  4,  2],
#         [ 1,  4,  2],
#         [ 3,  4,  2],
#         ...,
#         [ 6, 28, 34],
#         [ 5, 27, 33],
#         [ 4, 26, 32]],
#
#        [[ 2,  0,  0],
#         [ 6,  4,  4],
#         [ 8,  4,  3],
#         ...,
#         [ 4, 29, 33],
#         [ 6, 28, 33],
#         [ 7, 28, 30]],
#
#        ...,
#
#        [[29, 46, 33],
#         [21, 38, 25],
#         [10, 24, 12],
#         ...,
#         [ 3,  1,  1],
#         [ 3,  1,  1],
#         [ 3,  1,  1]],
#
#        [[30, 47, 34],
#         [20, 37, 24],
#         [ 9, 23, 11],
#         ...,
#         [ 3,  1,  1],
#         [ 3,  1,  1],
#         [ 3,  1,  1]],
#
#        [[27, 45, 32],
#         [19, 36, 23],
#         [10, 24, 12],
#         ...,
#         [ 3,  1,  1],
#         [ 3,  1,  1],
#         [ 3,  1,  1]]], dtype=uint8)}, {'box': [tensor(101., device='cuda:0'), tensor(202., device='cuda:0'), tensor(992., device='cuda:0'), tensor(715., device='cuda:0')], 'conf': tensor(0.57617, device='cuda:0'), 'cls': tensor(0., device='cuda:0'), 'label': 'person 0.58', 'im': array([[[ 47,  61,  83],
#         [ 47,  63,  86],
#         [ 53,  69,  92],
#         ...,
#         [106, 140, 210],
#         [126, 160, 230],
#         [149, 185, 249]],
#
#        [[ 42,  58,  87],
#         [ 46,  62,  91],
#         [ 48,  66,  97],
#         ...,
#         [104, 139, 207],
#         [126, 161, 225],
#         [163, 193, 250]],
#
#        [[ 48,  64,  93],
#         [ 48,  64,  93],
#         [ 49,  67,  98],
#         ...,
#         [105, 140, 206],
#         [126, 159, 222],
#         [159, 189, 244]],
#
#        ...,
#
#        [[ 50,  71, 103],
#         [ 59,  80, 112],
#         [ 64,  84, 115],
#         ...,
#         [ 12,  11,   7],
#         [ 10,  11,   7],
#         [ 12,  13,   9]],
#
#        [[ 53,  74, 106],
#         [ 59,  80, 112],
#         [ 64,  84, 115],
#         ...,
#         [ 14,  13,   9],
#         [ 12,  13,   9],
#         [ 14,  15,  11]],
#
#        [[ 56,  77, 109],
#         [ 55,  76, 107],
#         [ 62,  82, 113],
#         ...,
#         [ 15,  14,  10],
#         [ 14,  15,  11],
#         [ 15,  16,  12]]], dtype=uint8)}, {'box': [tensor(752., device='cuda:0'), tensor(46.75000, device='cuda:0'), tensor(1149., device='cuda:0'), tensor(715., device='cuda:0')], 'conf': tensor(0.87793, device='cuda:0'), 'cls': tensor(0., device='cuda:0'), 'label': 'person 0.88', 'im': array([[[82, 83, 93],
#         [83, 85, 93],
#         [85, 84, 93],
#         ...,
#         [19, 21, 21],
#         [19, 21, 21],
#         [23, 23, 23]],
#
#        [[83, 85, 95],
#         [86, 88, 96],
#         [87, 86, 95],
#         ...,
#         [19, 22, 20],
#         [22, 23, 21],
#         [23, 24, 22]],
#
#        [[84, 86, 96],
#         [88, 90, 98],
#         [87, 89, 97],
#         ...,
#         [19, 22, 20],
#         [23, 24, 22],
#         [24, 25, 23]],
#
#        ...,
#
#        [[62, 63, 53],
#         [62, 63, 53],
#         [63, 64, 54],
#         ...,
#         [37, 35, 24],
#         [38, 36, 25],
#         [38, 37, 23]],
#
#        [[62, 63, 53],
#         [64, 65, 55],
#         [62, 63, 53],
#         ...,
#         [36, 34, 23],
#         [37, 35, 24],
#         [35, 34, 20]],
#
#        [[65, 66, 56],
#         [63, 64, 54],
#         [62, 61, 51],
#         ...,
#         [36, 34, 23],
#         [34, 32, 21],
#         [32, 31, 17]]], dtype=uint8)}, {'box': [tensor(0.63281, device='cuda:0'), tensor(551.81250, device='cuda:0'), tensor(78.67969, device='cuda:0'), tensor(891., device='cuda:0')], 'conf': tensor(0.35596, device='cuda:0'), 'cls': tensor(0., device='cuda:0'), 'label': 'person 0.36', 'im': array([[[126, 117, 114],
#         [126, 120, 115],
#         [123, 120, 112],
#         ...,
#         [123, 153, 180],
#         [121, 151, 178],
#         [120, 150, 177]],
#
#        [[122, 120, 112],
#         [123, 120, 112],
#         [127, 119, 112],
#         ...,
#         [127, 158, 181],
#         [123, 154, 177],
#         [121, 151, 176]],
#
#        [[120, 117, 112],
#         [124, 121, 113],
#         [130, 122, 115],
#         ...,
#         [127, 158, 181],
#         [122, 153, 176],
#         [120, 150, 175]],
#
#        ...,
#
#        [[ 62,  54,  64],
#         [ 72,  64,  74],
#         [ 93,  85,  95],
#         ...,
#         [ 41,  60,  95],
#         [ 44,  63,  98],
#         [ 44,  63,  98]],
#
#        [[ 70,  62,  72],
#         [ 82,  74,  84],
#         [ 91,  83,  93],
#         ...,
#         [ 50,  70, 105],
#         [ 52,  72, 107],
#         [ 48,  68, 103]],
#
#        [[ 76,  68,  78],
#         [ 83,  75,  85],
#         [ 87,  79,  89],
#         ...,
#         [ 48,  66,  97],
#         [ 55,  73, 102],
#         [ 55,  73, 102]]], dtype=uint8)}, {'box': [tensor(23.83594, device='cuda:0'), tensor(215.15625, device='cuda:0'), tensor(802.40625, device='cuda:0'), tensor(779.62500, device='cuda:0')], 'conf': tensor(0.75684, device='cuda:0'), 'cls': tensor(5., device='cuda:0'), 'label': 'bus 0.76', 'im': array([[[ 96, 122, 129],
#         [ 87, 113, 120],
#         [  0,  21,  27],
#         ...,
#         [ 76,  74,  74],
#         [ 81,  79,  79],
#         [ 92,  93,  91]],
#
#        [[  0,   2,   9],
#         [  0,   0,   7],
#         [ 16,  42,  48],
#         ...,
#         [ 75,  70,  72],
#         [119, 112, 115],
#         [ 99,  92,  95]],
#
#        [[ 83, 109, 115],
#         [100, 119, 126],
#         [ 58,  77,  84],
#         ...,
#         [ 75,  69,  70],
#         [ 51,  45,  46],
#         [ 90,  84,  85]],
#
#        ...,
#
#        [[  4,   0,   5],
#         [  0,   0,   6],
#         [ 22,  23,  37],
#         ...,
#         [169, 171, 182],
#         [187, 189, 200],
#         [158, 160, 171]],
#
#        [[  2,   0,   3],
#         [ 12,  11,  21],
#         [ 54,  57,  72],
#         ...,
#         [139, 141, 152],
#         [194, 196, 207],
#         [213, 215, 226]],
#
#        [[  1,   0,   4],
#         [ 24,  25,  35],
#         [ 54,  59,  74],
#         ...,
#         [181, 183, 194],
#         [180, 182, 193],
#         [167, 169, 180]]], dtype=uint8)}, {'box': [tensor(50.20312, device='cuda:0'), tensor(398.46094, device='cuda:0'), tensor(243., device='cuda:0'), tensor(905.34375, device='cuda:0')], 'conf': tensor(0.80908, device='cuda:0'), 'cls': tensor(0., device='cuda:0'), 'label': 'person 0.81', 'im': array([[[ 76,  77,  67],
#         [101, 102,  92],
#         [103, 104,  94],
#         ...,
#         [ 21,   3,   2],
#         [ 23,   5,   4],
#         [ 22,   7,   5]],
#
#        [[ 78,  79,  69],
#         [102, 103,  93],
#         [102, 103,  93],
#         ...,
#         [ 20,   2,   1],
#         [ 22,   4,   3],
#         [ 18,   3,   1]],
#
#        [[ 63,  61,  53],
#         [ 86,  87,  78],
#         [ 79,  77,  69],
#         ...,
#         [ 22,   4,   3],
#         [ 23,   5,   4],
#         [ 23,   5,   4]],
#
#        ...,
#
#        [[212, 223, 227],
#         [217, 228, 232],
#         [220, 231, 235],
#         ...,
#         [207, 215, 228],
#         [209, 217, 230],
#         [209, 215, 228]],
#
#        [[224, 232, 239],
#         [229, 237, 244],
#         [224, 230, 237],
#         ...,
#         [204, 212, 225],
#         [208, 214, 227],
#         [212, 218, 229]],
#
#        [[143, 145, 156],
#         [123, 124, 134],
#         [105, 106, 116],
#         ...,
#         [206, 212, 223],
#         [211, 217, 228],
#         [206, 212, 223]]], dtype=uint8)}, {'box': [tensor(668.25000, device='cuda:0'), tensor(401.41406, device='cuda:0'), tensor(808.31250, device='cuda:0'), tensor(882.56250, device='cuda:0')], 'conf': tensor(0.82715, device='cuda:0'), 'cls': tensor(0., device='cuda:0'), 'label': 'person 0.83', 'im': array([[[ 58,  50,  50],
#         [ 66,  58,  58],
#         [ 59,  54,  53],
#         ...,
#         [ 82,  74,  74],
#         [ 81,  75,  76],
#         [ 75,  71,  76]],
#
#        [[ 61,  53,  53],
#         [ 74,  66,  66],
#         [ 60,  55,  54],
#         ...,
#         [ 79,  70,  73],
#         [ 82,  73,  76],
#         [ 77,  71,  76]],
#
#        [[ 64,  56,  56],
#         [ 68,  60,  60],
#         [ 57,  52,  51],
#         ...,
#         [ 75,  62,  70],
#         [ 72,  60,  66],
#         [ 62,  52,  58]],
#
#        ...,
#
#        [[ 69,  57,  63],
#         [ 76,  65,  68],
#         [ 77,  66,  69],
#         ...,
#         [174, 183, 196],
#         [126, 137, 151],
#         [123, 134, 148]],
#
#        [[ 94,  83,  86],
#         [ 89,  78,  81],
#         [ 86,  75,  78],
#         ...,
#         [206, 213, 222],
#         [205, 211, 222],
#         [195, 201, 212]],
#
#        [[ 99,  89,  95],
#         [ 90,  81,  84],
#         [ 76,  67,  70],
#         ...,
#         [204, 206, 214],
#         [215, 217, 225],
#         [219, 221, 229]]], dtype=uint8)}, {'box': [tensor(223.38281, device='cuda:0'), tensor(403.94531, device='cuda:0'), tensor(345.09375, device='cuda:0'), tensor(867.37500, device='cuda:0')], 'conf': tensor(0.86035, device='cuda:0'), 'cls': tensor(0., device='cuda:0'), 'label': 'person 0.86', 'im': array([[[ 69,  57,  55],
#         [ 68,  56,  54],
#         [ 65,  53,  51],
#         ...,
#         [ 51,  38,  30],
#         [ 49,  36,  28],
#         [ 52,  36,  29]],
#
#        [[ 69,  57,  55],
#         [ 69,  57,  55],
#         [ 65,  53,  51],
#         ...,
#         [ 51,  40,  32],
#         [ 51,  38,  30],
#         [ 54,  38,  31]],
#
#        [[ 68,  56,  54],
#         [ 67,  55,  53],
#         [ 62,  50,  48],
#         ...,
#         [ 52,  43,  34],
#         [ 52,  39,  31],
#         [ 52,  39,  31]],
#
#        ...,
#
#        [[186, 223, 245],
#         [185, 219, 242],
#         [174, 208, 231],
#         ...,
#         [132, 132, 138],
#         [137, 135, 141],
#         [110, 109, 113]],
#
#        [[124, 160, 178],
#         [157, 193, 211],
#         [186, 219, 239],
#         ...,
#         [146, 146, 152],
#         [146, 144, 150],
#         [153, 152, 156]],
#
#        [[200, 235, 249],
#         [202, 235, 251],
#         [197, 230, 246],
#         ...,
#         [153, 153, 159],
#         [150, 148, 154],
#         [148, 146, 152]]], dtype=uint8)}]

# %%
import time

print(time.ctime())
print(time.ctime().replace(" ", "-"))

import datetime
print(datetime.datetime.now().strftime("%m-%d-%Y-%H-%M-%S"))
# Out:
# Sun Nov 28 20:04:51 2021
# Sun-Nov-28-20:04:51-2021
# 11-28-2021-20-04-51
